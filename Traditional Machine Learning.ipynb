# %% [markdown]
# # KNN

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# %%
from zipfile import ZipFile
import os

# Path ke file zip yang sudah diupload
zip_file_path = '/content/Dataset.zip'  # Ganti dengan path file zip kamu

# Folder tujuan untuk mengekstrak file
extract_folder = '/content/'

# Ekstrak file zip
with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print(f"Dataset berhasil diekstrak ke {extract_folder}")
# Out:
# Dataset berhasil diekstrak ke /content/

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def load_images_and_labels(dataset_path):
    images = []
    labels = []
    label_map = {}
    label_count = 0

    for folder_name in os.listdir(dataset_path):
        person_folder = os.path.join(dataset_path, folder_name)

        if os.path.isdir(person_folder):
            # Hanya ambil gambar yang jumlahnya >= 5
            image_files = [f for f in os.listdir(person_folder) if f.endswith(('jpg', 'jpeg', 'png'))]
            if len(image_files) >= 5:
                label_map[label_count] = folder_name  # Menyimpan label ke nama orang
                for image_file in image_files:
                    img_path = os.path.join(person_folder, image_file)
                    img = cv2.imread(img_path)

                    # Mengkonversi gambar ke grayscale
                    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

                    # Mendeteksi wajah menggunakan Haar Cascade
                    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

                    # Hanya mengambil wajah yang terdeteksi
                    for (x, y, w, h) in faces:
                        face = img[y:y+h, x:x+w]  # Potong wajah
                        face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)  # Konversi ke RGB
                        face = cv2.resize(face, (224, 224))  # Resizing gambar ke ukuran yang sesuai untuk MobileNet
                        images.append(face)
                        labels.append(label_count)

                label_count += 1

    return np.array(images), np.array(labels), label_map

# %%
def extract_features(images, batch_size=32):
    model = MobileNetV2(weights='imagenet', include_top=False, pooling='avg')
    features = []

    # Memproses gambar dalam batch
    for i in range(0, len(images), batch_size):
        batch = images[i:i+batch_size]
        batch_features = model.predict(batch)
        features.append(batch_features)

    return np.vstack(features)  # Menggabungkan semua fitur dalam batch

# %%
dataset_path = '/content/Dataset'

# %%
images, labels, label_map = load_images_and_labels(dataset_path)

# %%
images = preprocess_input(images)

# %%
features = extract_features(images)
# Out:
# <ipython-input-5-8a7c93be1c7c>:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   model = MobileNetV2(weights='imagenet', include_top=False, pooling='avg')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Membagi data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
# Inisialisasi KNN dan melatih model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Memprediksi pada data uji
y_pred = knn.predict(X_test)

# Evaluasi akurasi model
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi KNN: {accuracy * 100:.2f}%")
# Out:
# Akurasi KNN: 24.79%

# %%
for i in range(len(y_test)):
    print(f"Prediksi: {label_map[y_pred[i]]}, Asli: {label_map[y_test[i]]}")
# Out:
# Prediksi: Mike_Krzyzewski, Asli: Carlos_Moya
# Prediksi: Tony_Blair, Asli: Alejandro_Toledo
# Prediksi: Rudolph_Giuliani, Asli: Ariel_Sharon
# Prediksi: Abdullah_Gul, Asli: Nicanor_Duarte_Frutos
# Prediksi: Carlos_Menem, Asli: Rob_Marshall
# Prediksi: Angelina_Jolie, Asli: Carrie-Anne_Moss
# Prediksi: Ron_Dittemore, Asli: Alvaro_Uribe
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Colin_Powell, Asli: Kofi_Annan
# Prediksi: Michael_Bloomberg, Asli: Frank_Solich
# Prediksi: Scott_Peterson, Asli: Gwyneth_Paltrow
# Prediksi: Ariel_Sharon, Asli: Colin_Powell
# Prediksi: Jean-David_Levitte, Asli: Condoleezza_Rice
# Prediksi: George_Clooney, Asli: Thaksin_Shinawatra
# Prediksi: Tony_Blair, Asli: Hamid_Karzai
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Colin_Powell, Asli: Hu_Jintao
# Prediksi: Cameron_Diaz, Asli: Renee_Zellweger
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: Hugh_Grant
# Prediksi: Tom_Ridge, Asli: Joe_Lieberman
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: Tony_Blair, Asli: Guillermo_Coria
# Prediksi: Walter_Mondale, Asli: Tony_Blair
# Prediksi: Bertie_Ahern, Asli: Hugo_Chavez
# Prediksi: Tom_Ridge, Asli: Tom_Ridge
# Prediksi: Gerhard_Schroeder, Asli: John_McCain
# Prediksi: Hans_Blix, Asli: Donald_Rumsfeld
# Prediksi: Tony_Blair, Asli: Jesse_Jackson
# Prediksi: Tony_Blair, Asli: Colin_Powell
# Prediksi: Vojislav_Kostunica, Asli: Vicente_Fox
# Prediksi: Bill_Gates, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: John_Travolta
# Prediksi: Chanda_Rubin, Asli: Condoleezza_Rice
# Prediksi: Vladimir_Putin, Asli: Vladimir_Putin
# Prediksi: Jennifer_Aniston, Asli: Jennifer_Aniston
# Prediksi: Junichiro_Koizumi, Asli: Naomi_Watts
# Prediksi: Abdullah_Gul, Asli: Donald_Rumsfeld
# Prediksi: Ariel_Sharon, Asli: Ricardo_Lagos
# Prediksi: Colin_Powell, Asli: John_Ashcroft
# Prediksi: Robert_Duvall, Asli: Tony_Blair
# Prediksi: Jiri_Novak, Asli: Jiri_Novak
# Prediksi: Recep_Tayyip_Erdogan, Asli: Recep_Tayyip_Erdogan
# Prediksi: Ana_Guevara, Asli: Lleyton_Hewitt
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Ariel_Sharon, Asli: Gunter_Pleuger
# Prediksi: Andre_Agassi, Asli: Andre_Agassi
# Prediksi: Ariel_Sharon, Asli: Abdullah_Gul
# Prediksi: Sergey_Lavrov, Asli: Ali_Naimi
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: John_Negroponte, Asli: Ariel_Sharon
# Prediksi: Mahmoud_Abbas, Asli: Paul_Martin
# Prediksi: William_Macy, Asli: Jean-David_Levitte
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Mike_Krzyzewski, Asli: Tommy_Thompson
# Prediksi: Nicanor_Duarte_Frutos, Asli: Tony_Blair
# Prediksi: Shimon_Peres, Asli: Mahmoud_Abbas
# Prediksi: Hugo_Chavez, Asli: Joe_Lieberman
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: George_Pataki
# Prediksi: Lindsay_Davenport, Asli: Andre_Agassi
# Prediksi: Amelie_Mauresmo, Asli: Amelie_Mauresmo
# Prediksi: Scott_McClellan, Asli: Jennifer_Aniston
# Prediksi: Jean_Chretien, Asli: Jean_Chretien
# Prediksi: Igor_Ivanov, Asli: John_Paul_II
# Prediksi: John_Ashcroft, Asli: John_Ashcroft
# Prediksi: Spencer_Abraham, Asli: David_Nalbandian
# Prediksi: Kevin_Costner, Asli: Tom_Hanks
# Prediksi: Donald_Rumsfeld, Asli: Enrique_Bolanos
# Prediksi: Ariel_Sharon, Asli: Naji_Sabri
# Prediksi: Norm_Coleman, Asli: Tony_Blair
# Prediksi: Hamid_Karzai, Asli: Hamid_Karzai
# Prediksi: Michael_Bloomberg, Asli: David_Beckham
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Alejandro_Toledo, Asli: Gloria_Macapagal_Arroyo
# Prediksi: Vladimir_Putin, Asli: Serena_Williams
# Prediksi: Hugo_Chavez, Asli: William_Ford_Jr
# Prediksi: Kim_Clijsters, Asli: Rubens_Barrichello
# Prediksi: Vaclav_Havel, Asli: Roh_Moo-hyun
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Jonathan_Edwards, Asli: Tom_Daschle
# Prediksi: Javier_Solana, Asli: Robert_De_Niro
# Prediksi: Jonathan_Edwards, Asli: Carlos_Moya
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Jeremy_Greenstock, Asli: Joe_Lieberman
# Prediksi: Recep_Tayyip_Erdogan, Asli: Gordon_Brown
# Prediksi: Junichiro_Koizumi, Asli: David_Beckham
# Prediksi: Lucy_Liu, Asli: Carmen_Electra
# Prediksi: Chen_Shui-bian, Asli: Jean_Chretien
# Prediksi: Emma_Watson, Asli: Megawati_Sukarnoputri
# Prediksi: Dick_Cheney, Asli: Peter_Struck
# Prediksi: Jeb_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Serena_Williams
# Prediksi: Saddam_Hussein, Asli: Saddam_Hussein
# Prediksi: Nestor_Kirchner, Asli: Robert_Duvall
# Prediksi: Britney_Spears, Asli: Celine_Dion
# Prediksi: Michael_Bloomberg, Asli: Prince_Charles
# Prediksi: Lance_Bass, Asli: Pete_Sampras
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Charles_Taylor, Asli: Charles_Taylor
# Prediksi: Norah_Jones, Asli: Jennifer_Lopez
# Prediksi: Jay_Garner, Asli: Donald_Rumsfeld
# Prediksi: Donald_Rumsfeld, Asli: Jacques_Chirac
# Prediksi: Bill_Clinton, Asli: Tommy_Thompson
# Prediksi: Ana_Guevara, Asli: Pete_Sampras
# Prediksi: Kevin_Costner, Asli: George_W_Bush
# Prediksi: Jean_Chretien, Asli: Jean_Chretien
# Prediksi: Colin_Powell, Asli: Kim_Ryong-sung
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Nestor_Kirchner, Asli: Vladimir_Putin
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Martin_Scorsese, Asli: Gray_Davis
# Prediksi: Tom_Daschle, Asli: Recep_Tayyip_Erdogan
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Saddam_Hussein, Asli: Saddam_Hussein
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Mohammed_Al-Douri
# Prediksi: Hugh_Grant, Asli: Cesar_Gaviria
# Prediksi: Billy_Crystal, Asli: Luis_Horna
# Prediksi: Hugo_Chavez, Asli: Hugo_Chavez
# Prediksi: Matthew_Perry, Asli: Tom_Crean
# Prediksi: Al_Gore, Asli: Sourav_Ganguly
# Prediksi: Jason_Kidd, Asli: Nestor_Kirchner
# Prediksi: John_Ashcroft, Asli: Norm_Coleman
# Prediksi: Michael_Bloomberg, Asli: Taha_Yassin_Ramadan
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Junichiro_Koizumi, Asli: Li_Zhaoxing
# Prediksi: Jeremy_Greenstock, Asli: Sergey_Lavrov
# Prediksi: George_W_Bush, Asli: Carlos_Moya
# Prediksi: Roman_Polanski, Asli: Martin_Scorsese
# Prediksi: Scott_Peterson, Asli: Serena_Williams
# Prediksi: Roman_Polanski, Asli: Paul_McCartney
# Prediksi: Dennis_Kucinich, Asli: Paul_McCartney
# Prediksi: Jennifer_Capriati, Asli: Richard_Gere
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Bill_Clinton, Asli: Bob_Hope
# Prediksi: Recep_Tayyip_Erdogan, Asli: Ralf_Schumacher
# Prediksi: Donald_Rumsfeld, Asli: Junichiro_Koizumi
# Prediksi: Roman_Polanski, Asli: Lance_Armstrong
# Prediksi: Sylvester_Stallone, Asli: Tom_Daschle
# Prediksi: Norah_Jones, Asli: Mariah_Carey
# Prediksi: Michelle_Kwan, Asli: Laura_Bush
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Roman_Polanski, Asli: Lucio_Gutierrez
# Prediksi: Michelle_Kwan, Asli: Amelia_Vega
# Prediksi: Silvan_Shalom, Asli: Abdullah_Gul
# Prediksi: Venus_Williams, Asli: Serena_Williams
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Hamid_Karzai
# Prediksi: Bill_Clinton, Asli: Bill_Clinton
# Prediksi: Vicente_Fox, Asli: Bill_Simon
# Prediksi: Michael_Bloomberg, Asli: Boris_Becker
# Prediksi: Bill_Gates, Asli: Spencer_Abraham
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Charles_Taylor, Asli: Fidel_Castro
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Tommy_Franks, Asli: Arnold_Schwarzenegger
# Prediksi: Bill_Graham, Asli: Jack_Straw
# Prediksi: Charles_Taylor, Asli: Charles_Taylor
# Prediksi: Norah_Jones, Asli: Julianne_Moore
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: John_Ashcroft, Asli: Hal_Gehman
# Prediksi: Hosni_Mubarak, Asli: Shimon_Peres
# Prediksi: Richard_Gere, Asli: Richard_Gere
# Prediksi: Jeb_Bush, Asli: Pedro_Almodovar
# Prediksi: George_W_Bush, Asli: Paul_Martin
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Ben_Affleck
# Prediksi: Tony_Blair, Asli: Michael_Bloomberg
# Prediksi: Sergey_Lavrov, Asli: Wayne_Ferreira
# Prediksi: Heizo_Takenaka, Asli: Heizo_Takenaka
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Silvio_Berlusconi, Asli: Gregg_Popovich
# Prediksi: Michael_Bloomberg, Asli: Jean_Charest
# Prediksi: Robert_Blake, Asli: Mahmoud_Abbas
# Prediksi: Norah_Jones, Asli: Norah_Jones
# Prediksi: Tom_Ridge, Asli: Bill_Clinton
# Prediksi: Donald_Rumsfeld, Asli: Geoff_Hoon
# Prediksi: Jonathan_Edwards, Asli: Abdullah_Gul
# Prediksi: Catherine_Deneuve, Asli: Michael_Phelps
# Prediksi: Tom_Ridge, Asli: Michael_Powell
# Prediksi: Hugh_Grant, Asli: Amelia_Vega
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Mike_Martz, Asli: Colin_Powell
# Prediksi: Tony_Blair, Asli: Igor_Ivanov
# Prediksi: Donald_Rumsfeld, Asli: Nicanor_Duarte_Frutos
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Mark_Philippoussis, Asli: David_Nalbandian
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Zhu_Rongji, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Oscar_De_La_Hoya, Asli: Bill_Simon
# Prediksi: Megawati_Sukarnoputri, Asli: Megawati_Sukarnoputri
# Prediksi: Lance_Bass, Asli: Alastair_Campbell
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Laura_Bush
# Prediksi: Jacques_Rogge, Asli: Alejandro_Toledo
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Roman_Polanski, Asli: Charles_Moose
# Prediksi: Colin_Powell, Asli: Fernando_Henrique_Cardoso
# Prediksi: Colin_Powell, Asli: Vladimir_Putin
# Prediksi: Richard_Armitage, Asli: George_W_Bush
# Prediksi: Michael_Schumacher, Asli: Michael_Schumacher
# Prediksi: Natalie_Maines, Asli: Gwyneth_Paltrow
# Prediksi: Al_Gore, Asli: George_Clooney
# Prediksi: Matthew_Perry, Asli: Tony_Blair
# Prediksi: Kim_Clijsters, Asli: Anna_Kournikova
# Prediksi: Richard_Myers, Asli: Nestor_Kirchner
# Prediksi: Tony_Blair, Asli: Ricardo_Lagos
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Elizabeth_Hurley, Asli: Jennifer_Lopez
# Prediksi: Gerhard_Schroeder, Asli: Arnold_Schwarzenegger
# Prediksi: Li_Zhaoxing, Asli: Roh_Moo-hyun
# Prediksi: Robert_Blake, Asli: Robert_Blake
# Prediksi: George_W_Bush, Asli: Richard_Myers
# Prediksi: Mike_Martz, Asli: Megawati_Sukarnoputri
# Prediksi: Saddam_Hussein, Asli: Saddam_Hussein
# Prediksi: Donald_Rumsfeld, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Peter_Struck
# Prediksi: George_W_Bush, Asli: Celine_Dion
# Prediksi: Jack_Straw, Asli: Jack_Straw
# Prediksi: Nancy_Pelosi, Asli: George_W_Bush
# Prediksi: Rudolph_Giuliani, Asli: Tony_Blair
# Prediksi: Colin_Powell, Asli: John_Paul_II
# Prediksi: John_Ashcroft, Asli: Tom_Ridge
# Prediksi: Junichiro_Koizumi, Asli: Hugo_Chavez
# Prediksi: Robert_Zoellick, Asli: Jeremy_Greenstock
# Prediksi: Colin_Powell, Asli: Richard_Armitage
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: Gerhard_Schroeder, Asli: John_Howard
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: Tony_Blair
# Prediksi: Recep_Tayyip_Erdogan, Asli: Angelina_Jolie
# Prediksi: Nestor_Kirchner, Asli: Natalie_Coughlin
# Prediksi: George_W_Bush, Asli: Tom_Daschle
# Prediksi: Roman_Polanski, Asli: Carlos_Menem
# Prediksi: Nestor_Kirchner, Asli: Rudolph_Giuliani
# Prediksi: Roman_Polanski, Asli: Hu_Jintao
# Prediksi: Donald_Rumsfeld, Asli: Paul_Bremer
# Prediksi: Cruz_Bustamante, Asli: Alvaro_Uribe
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: Tony_Blair, Asli: John_Ashcroft
# Prediksi: Cameron_Diaz, Asli: Holly_Hunter
# Prediksi: Ariel_Sharon, Asli: Meryl_Streep
# Prediksi: George_W_Bush, Asli: Paul_Bremer
# Prediksi: Igor_Ivanov, Asli: Jean_Chretien
# Prediksi: John_Ashcroft, Asli: Alejandro_Toledo
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Kevin_Costner, Asli: Pierce_Brosnan
# Prediksi: Roh_Moo-hyun, Asli: Roh_Moo-hyun
# Prediksi: Jennifer_Aniston, Asli: Sharon_Stone
# Prediksi: George_W_Bush, Asli: David_Beckham
# Prediksi: Tim_Henman, Asli: Tim_Henman
# Prediksi: Michael_Bloomberg, Asli: Robert_Mueller
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Roman_Polanski, Asli: Thabo_Mbeki
# Prediksi: Sarah_Hughes, Asli: Sarah_Hughes
# Prediksi: Hillary_Clinton, Asli: Hillary_Clinton
# Prediksi: Geoff_Hoon, Asli: Tom_Cruise
# Prediksi: Lleyton_Hewitt, Asli: Lleyton_Hewitt
# Prediksi: Nestor_Kirchner, Asli: Marco_Antonio_Barrera
# Prediksi: Oscar_De_La_Hoya, Asli: Tommy_Franks
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Ariel_Sharon, Asli: Tariq_Aziz
# Prediksi: George_W_Bush, Asli: Hugo_Chavez
# Prediksi: Ray_Romano, Asli: Carrie-Anne_Moss
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: George_W_Bush, Asli: Jean_Charest
# Prediksi: George_W_Bush, Asli: Vladimir_Putin
# Prediksi: Tony_Blair, Asli: Ron_Dittemore
# Prediksi: Mike_Krzyzewski, Asli: Mike_Krzyzewski
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Vojislav_Kostunica, Asli: Pete_Sampras
# Prediksi: Jonathan_Edwards, Asli: Andre_Agassi
# Prediksi: Hugo_Chavez, Asli: John_Travolta
# Prediksi: Ari_Fleischer, Asli: Ari_Fleischer
# Prediksi: Juan_Carlos_Ferrero, Asli: Juan_Carlos_Ferrero
# Prediksi: Rob_Marshall, Asli: King_Abdullah_II
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: Enrique_Bolanos
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Donald_Rumsfeld, Asli: Hugo_Chavez
# Prediksi: Spencer_Abraham, Asli: Hu_Jintao
# Prediksi: Jiang_Zemin, Asli: Jiang_Zemin
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Hugo_Chavez, Asli: Gerhard_Schroeder
# Prediksi: John_Ashcroft, Asli: Laura_Bush
# Prediksi: Colin_Powell, Asli: Silvio_Berlusconi
# Prediksi: Ana_Guevara, Asli: Pete_Sampras
# Prediksi: Frank_Solich, Asli: Justin_Timberlake
# Prediksi: Richard_Virenque, Asli: Li_Peng
# Prediksi: Hamid_Karzai, Asli: Hamid_Karzai
# Prediksi: Tony_Blair, Asli: Saddam_Hussein
# Prediksi: Donald_Rumsfeld, Asli: Queen_Elizabeth_II
# Prediksi: Kofi_Annan, Asli: Kofi_Annan
# Prediksi: George_W_Bush, Asli: Meryl_Streep
# Prediksi: William_Donaldson, Asli: Boris_Becker
# Prediksi: Ray_Romano, Asli: Fernando_Gonzalez
# Prediksi: Junichiro_Koizumi, Asli: Jacques_Chirac
# Prediksi: Kim_Clijsters, Asli: Justin_Timberlake
# Prediksi: Hans_Blix, Asli: Hans_Blix
# Prediksi: Donald_Rumsfeld, Asli: Kofi_Annan
# Prediksi: George_W_Bush, Asli: Bob_Stoops
# Prediksi: Juan_Carlos_Ferrero, Asli: Juan_Carlos_Ferrero
# Prediksi: Jonathan_Edwards, Asli: Hugo_Chavez
# Prediksi: Jiang_Zemin, Asli: Owen Tamashi Buntoro
# Prediksi: Bill_Gates, Asli: Tony_Blair
# Prediksi: Jean_Charest, Asli: Junichiro_Koizumi
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Ariel_Sharon, Asli: Richard_Myers
# Prediksi: Mike_Myers, Asli: John_Ashcroft
# Prediksi: Clay_Aiken, Asli: Silvio_Berlusconi
# Prediksi: Nestor_Kirchner, Asli: George_W_Bush
# Prediksi: Jean_Charest, Asli: Howard_Dean
# Prediksi: Valentino_Rossi, Asli: Valentino_Rossi
# Prediksi: Tony_Blair, Asli: George_W_Bush
# Prediksi: Nestor_Kirchner, Asli: Silvio_Berlusconi
# Prediksi: Tony_Blair, Asli: Winona_Ryder
# Prediksi: Norah_Jones, Asli: Angelina_Jolie
# Prediksi: Tony_Blair, Asli: Bill_Clinton
# Prediksi: John_Manley, Asli: Kim_Dae-jung
# Prediksi: Sergio_Vieira_De_Mello, Asli: William_Donaldson
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Kofi_Annan
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: Tony_Blair, Asli: Scott_McClellan
# Prediksi: Igor_Ivanov, Asli: Jean_Chretien
# Prediksi: Jiang_Zemin, Asli: Pervez_Musharraf
# Prediksi: Heizo_Takenaka, Asli: Gloria_Macapagal_Arroyo
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: John_Ashcroft, Asli: David_Nalbandian
# Prediksi: Hillary_Clinton, Asli: Mariah_Carey
# Prediksi: Jeb_Bush, Asli: Xavier_Malisse
# Prediksi: Cameron_Diaz, Asli: Cameron_Diaz
# Prediksi: Ariel_Sharon, Asli: Saddam_Hussein
# Prediksi: Hugo_Chavez, Asli: Hugo_Chavez
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Andre_Agassi, Asli: Jose_Maria_Aznar
# Prediksi: Nancy_Pelosi, Asli: Amelie_Mauresmo
# Prediksi: Hugo_Chavez, Asli: Sarah_Jessica_Parker
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Matthew_Perry, Asli: Hugh_Grant
# Prediksi: Fernando_Henrique_Cardoso, Asli: Michael_Bloomberg
# Prediksi: Joschka_Fischer, Asli: Hamid_Karzai
# Prediksi: Nestor_Kirchner, Asli: Nestor_Kirchner
# Prediksi: Tony_Blair, Asli: Ben_Affleck
# Prediksi: John_Ashcroft, Asli: Jacques_Chirac
# Prediksi: Tony_Blair, Asli: Jennifer_Capriati
# Prediksi: Scott_Peterson, Asli: Serena_Williams
# Prediksi: Saddam_Hussein, Asli: Saddam_Hussein
# Prediksi: Norm_Coleman, Asli: Recep_Tayyip_Erdogan
# Prediksi: Maria_Shriver, Asli: Jennifer_Aniston
# Prediksi: Roman_Polanski, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Lleyton_Hewitt, Asli: Lleyton_Hewitt
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Kim_Clijsters, Asli: Kim_Clijsters
# Prediksi: John_Kerry, Asli: Albert_Costa
# Prediksi: Tony_Blair, Asli: John_Ashcroft
# Prediksi: Lance_Armstrong, Asli: Sylvester_Stallone
# Prediksi: Vladimir_Putin, Asli: Vladimir_Putin
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Dennis_Hastert
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Nancy_Pelosi, Asli: Nancy_Pelosi
# Prediksi: Donald_Rumsfeld, Asli: Paul_Bremer
# Prediksi: Carmen_Electra, Asli: Amelia_Vega
# Prediksi: John_Bolton, Asli: John_Bolton
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Lance_Bass, Asli: Arnold_Schwarzenegger
# Prediksi: Spencer_Abraham, Asli: Pedro_Almodovar
# Prediksi: Juan_Carlos_Ferrero, Asli: Paul_Wolfowitz
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: Norah_Jones, Asli: Susan_Sarandon
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: George_W_Bush, Asli: Silvio_Berlusconi
# Prediksi: Venus_Williams, Asli: Venus_Williams
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: John_Ashcroft, Asli: John_Ashcroft
# Prediksi: Colin_Powell, Asli: Andre_Agassi
# Prediksi: Hugo_Chavez, Asli: Jacques_Chirac
# Prediksi: Tom_Ridge, Asli: Bob_Graham
# Prediksi: Jeremy_Greenstock, Asli: Jeremy_Greenstock
# Prediksi: Jennifer_Aniston, Asli: Jennifer_Aniston
# Prediksi: Jean_Charest, Asli: Yao_Ming
# Prediksi: Holly_Hunter, Asli: Diana_Krall
# Prediksi: Colin_Powell, Asli: Tony_Blair
# Prediksi: Tony_Blair, Asli: Lleyton_Hewitt
# Prediksi: George_W_Bush, Asli: Muhammad_Ali
# Prediksi: George_W_Bush, Asli: Bill_Simon
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Maria_Shriver
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Jose_Manuel_Durao_Barroso
# Prediksi: Gerhard_Schroeder, Asli: Jack_Straw
# Prediksi: Alvaro_Uribe, Asli: Alvaro_Uribe
# Prediksi: Donald_Rumsfeld, Asli: Gerhard_Schroeder
# Prediksi: Lance_Bass, Asli: Jonathan_Edwards
# Prediksi: Pedro_Almodovar, Asli: Pedro_Almodovar
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Kim_Clijsters, Asli: Kim_Clijsters
# Prediksi: Jeremy_Greenstock, Asli: Alejandro_Toledo
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: Mahmoud_Abbas, Asli: Alvaro_Uribe
# Prediksi: Hans_Blix, Asli: Alvaro_Uribe
# Prediksi: Colin_Powell, Asli: Dennis_Kucinich
# Prediksi: Ana_Guevara, Asli: Paula_Radcliffe
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Tim_Henman
# Prediksi: Lance_Armstrong, Asli: Robert_Redford
# Prediksi: Gerhard_Schroeder, Asli: Junichiro_Koizumi
# Prediksi: Norah_Jones, Asli: Norah_Jones
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Valentino_Rossi, Asli: Rubens_Barrichello
# Prediksi: George_Clooney, Asli: Sylvester_Stallone
# Prediksi: Tony_Blair, Asli: Rubens_Barrichello
# Prediksi: Tony_Blair, Asli: Paul_Burrell
# Prediksi: Mahmoud_Abbas, Asli: Jose_Maria_Aznar
# Prediksi: Charles_Taylor, Asli: Jesse_Jackson
# Prediksi: Tony_Blair, Asli: Harrison_Ford
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Bill_Clinton, Asli: Donald_Rumsfeld
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Ron_Dittemore, Asli: Elton_John
# Prediksi: Shimon_Peres, Asli: Shimon_Peres
# Prediksi: Pierce_Brosnan, Asli: Gordon_Brown
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: Hugo_Chavez
# Prediksi: Eduardo_Duhalde, Asli: Eduardo_Duhalde
# Prediksi: John_Ashcroft, Asli: Joe_Lieberman
# Prediksi: George_W_Bush, Asli: Richard_Myers
# Prediksi: John_Edwards, Asli: Junichiro_Koizumi
# Prediksi: Colin_Powell, Asli: Choi_Sung-hong
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Denzel_Washington
# Prediksi: Russell_Simmons, Asli: Russell_Simmons
# Prediksi: Donald_Rumsfeld, Asli: Jack_Straw
# Prediksi: Gerhard_Schroeder, Asli: Vicente_Fernandez
# Prediksi: Lance_Armstrong, Asli: George_W_Bush
# Prediksi: Hugo_Chavez, Asli: Vicente_Fox
# Prediksi: Tang_Jiaxuan, Asli: Tang_Jiaxuan
# Prediksi: Ariel_Sharon, Asli: George_Robertson
# Prediksi: Natalie_Coughlin, Asli: Saddam_Hussein
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Mahmoud_Abbas, Asli: John_Howard
# Prediksi: Natalie_Coughlin, Asli: Megawati_Sukarnoputri
# Prediksi: Robert_Duvall, Asli: David_Beckham
# Prediksi: John_Travolta, Asli: James_Kelly
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: Ray_Romano, Asli: Vladimir_Putin
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Ciro_Gomes, Asli: Yoriko_Kawaguchi
# Prediksi: Grant_Hackett, Asli: Juan_Carlos_Ferrero
# Prediksi: Tony_Blair, Asli: Michael_Powell
# Prediksi: Hugo_Chavez, Asli: Alejandro_Toledo
# Prediksi: Jon_Gruden, Asli: John_McCain
# Prediksi: Liza_Minnelli, Asli: Erika_Harold
# Prediksi: Charlton_Heston, Asli: Jack_Straw
# Prediksi: Christine_Todd_Whitman, Asli: George_W_Bush
# Prediksi: Robert_Duvall, Asli: Bob_Stoops
# Prediksi: John_Ashcroft, Asli: Andy_Roddick
# Prediksi: Gonzalo_Sanchez_de_Lozada, Asli: Costas_Simitis
# Prediksi: Donald_Rumsfeld, Asli: Yao_Ming
# Prediksi: Laura_Bush, Asli: Martina_McBride
# Prediksi: Hans_Blix, Asli: Li_Peng
# Prediksi: Britney_Spears, Asli: Nicole_Kidman
# Prediksi: Hugo_Chavez, Asli: Carlos_Menem
# Prediksi: Richard_Virenque, Asli: Rudolph_Giuliani
# Prediksi: Arminio_Fraga, Asli: Michael_Chiklis
# Prediksi: Ray_Romano, Asli: Clint_Eastwood
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Recep_Tayyip_Erdogan, Asli: Al_Sharpton
# Prediksi: Matthew_Perry, Asli: George_W_Bush
# Prediksi: Howard_Dean, Asli: Gonzalo_Sanchez_de_Lozada
# Prediksi: Ariel_Sharon, Asli: Alejandro_Toledo
# Prediksi: Tiger_Woods, Asli: Tiger_Woods
# Prediksi: Julie_Gerberding, Asli: Julie_Gerberding
# Prediksi: Lance_Armstrong, Asli: Tom_Ridge
# Prediksi: James_Blake, Asli: John_Allen_Muhammad
# Prediksi: Holly_Hunter, Asli: Diana_Krall
# Prediksi: Donald_Rumsfeld, Asli: John_Paul_II
# Prediksi: Anna_Kournikova, Asli: Jim_Furyk
# Prediksi: Nicanor_Duarte_Frutos, Asli: Hugo_Chavez
# Prediksi: Hugo_Chavez, Asli: Ray_Romano
# Prediksi: Abdullah_Gul, Asli: Vicente_Fox
# Prediksi: George_W_Bush, Asli: Silvio_Berlusconi
# Prediksi: Tom_Ridge, Asli: Jose_Maria_Aznar
# Prediksi: Colin_Powell, Asli: Jean_Chretien
# Prediksi: Colin_Powell, Asli: Ariel_Sharon
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Nestor_Kirchner, Asli: Paul_McCartney
# Prediksi: Igor_Ivanov, Asli: Heizo_Takenaka
# Prediksi: Donald_Rumsfeld, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Gordon_Brown, Asli: Gordon_Brown
# Prediksi: Valery_Giscard_dEstaing, Asli: Valery_Giscard_dEstaing
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Abdullah_Gul
# Prediksi: Leonardo_DiCaprio, Asli: Leonardo_DiCaprio
# Prediksi: Silvan_Shalom, Asli: Alejandro_Toledo
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Colin_Powell, Asli: George_W_Bush
# Prediksi: Jiang_Zemin, Asli: Jiang_Zemin
# Prediksi: Hugo_Chavez, Asli: Jose_Manuel_Durao_Barroso
# Prediksi: Hans_Blix, Asli: Ron_Dittemore
# Prediksi: Nestor_Kirchner, Asli: Edward_Lu
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Tony_Stewart
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: Gerhard_Schroeder
# Prediksi: George_W_Bush, Asli: Alejandro_Toledo
# Prediksi: Tony_Blair, Asli: George_W_Bush
# Prediksi: Arminio_Fraga, Asli: Michael_Schumacher
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: Igor_Ivanov, Asli: Jean_Chretien
# Prediksi: Pervez_Musharraf, Asli: Pervez_Musharraf
# Prediksi: Rendy Susanto, Asli: Rendy Susanto
# Prediksi: Tony_Blair, Asli: Amelie_Mauresmo
# Prediksi: Kim_Clijsters, Asli: Adrien_Brody
# Prediksi: Roman_Polanski, Asli: Lindsay_Davenport
# Prediksi: Donald_Rumsfeld, Asli: Tom_Crean
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Donald_Rumsfeld, Asli: Tang_Jiaxuan
# Prediksi: Norm_Coleman, Asli: Keanu_Reeves
# Prediksi: Tony_Blair, Asli: Vicente_Fox
# Prediksi: Gwyneth_Paltrow, Asli: Naomi_Watts
# Prediksi: Silvio_Berlusconi, Asli: George_Clooney
# Prediksi: Matthew_Perry, Asli: Carlos_Menem
# Prediksi: Norah_Jones, Asli: Laura_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Vicente_Fox, Asli: Vicente_Fox
# Prediksi: Nestor_Kirchner, Asli: Javier_Solana
# Prediksi: Jose_Manuel_Durao_Barroso, Asli: Ricardo_Lagos
# Prediksi: Gonzalo_Sanchez_de_Lozada, Asli: Arminio_Fraga
# Prediksi: Mahmoud_Abbas, Asli: Mahmoud_Abbas
# Prediksi: George_W_Bush, Asli: George_HW_Bush
# Prediksi: Renee_Zellweger, Asli: Mike_Myers
# Prediksi: Eduard_Shevardnadze, Asli: Igor_Ivanov
# Prediksi: Celine_Dion, Asli: Catherine_Zeta-Jones
# Prediksi: Gordon_Brown, Asli: Michael_Powell
# Prediksi: Hugo_Chavez, Asli: Hugo_Chavez
# Prediksi: Pierce_Brosnan, Asli: Gerhard_Schroeder
# Prediksi: Hugo_Chavez, Asli: Venus_Williams
# Prediksi: Kristanna_Loken, Asli: Jennifer_Garner
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Tommy_Haas
# Prediksi: Maria_Shriver, Asli: Ariel_Sharon
# Prediksi: Bill_Clinton, Asli: Queen_Elizabeth_II
# Prediksi: Nestor_Kirchner, Asli: Roh_Moo-hyun
# Prediksi: Colin_Powell, Asli: George_W_Bush
# Prediksi: Sergey_Lavrov, Asli: Tom_Daschle
# Prediksi: Vicente_Fox, Asli: Cesar_Gaviria
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_Clooney, Asli: George_Clooney
# Prediksi: Gerhard_Schroeder, Asli: George_W_Bush
# Prediksi: Hans_Blix, Asli: Alvaro_Uribe
# Prediksi: John_Kerry, Asli: Laura_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Roman_Polanski, Asli: Nestor_Kirchner
# Prediksi: John_Ashcroft, Asli: Gray_Davis
# Prediksi: Billy_Crystal, Asli: Kevin_Spacey
# Prediksi: Robert_Duvall, Asli: Alastair_Campbell
# Prediksi: Donald_Rumsfeld, Asli: Queen_Elizabeth_II
# Prediksi: John_Ashcroft, Asli: Boris_Becker
# Prediksi: Nancy_Pelosi, Asli: Naomi_Watts
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Xanana_Gusmao
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Mahmoud_Abbas, Asli: Eduardo_Duhalde
# Prediksi: Abdullah_Gul, Asli: Recep_Tayyip_Erdogan
# Prediksi: Robert_Duvall, Asli: Robert_Duvall
# Prediksi: Hosni_Mubarak, Asli: Dominique_de_Villepin
# Prediksi: Gerhard_Schroeder, Asli: George_W_Bush
# Prediksi: Vladimir_Putin, Asli: Ariel_Sharon
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Lucy_Liu, Asli: Jennifer_Aniston
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Tony_Blair, Asli: Mahathir_Mohamad
# Prediksi: Gwyneth_Paltrow, Asli: Julianne_Moore
# Prediksi: Donald_Rumsfeld, Asli: George_W_Bush
# Prediksi: John_Edwards, Asli: George_Clooney
# Prediksi: Gerhard_Schroeder, Asli: George_W_Bush
# Prediksi: Pervez_Musharraf, Asli: Pervez_Musharraf
# Prediksi: Jennifer_Garner, Asli: Madonna
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Lindsay_Davenport, Asli: Luis_Horna
# Prediksi: Bob_Hope, Asli: Recep_Tayyip_Erdogan
# Prediksi: John_Ashcroft, Asli: Hugo_Chavez
# Prediksi: Ray_Romano, Asli: Halle_Berry
# Prediksi: Atal_Bihari_Vajpayee, Asli: Atal_Bihari_Vajpayee
# Prediksi: Colin_Powell, Asli: Mahmoud_Abbas
# Prediksi: Lindsay_Davenport, Asli: Monica_Seles
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Scott_McClellan, Asli: Michael_Chiklis
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Donald_Rumsfeld, Asli: Jeong_Se-hyun
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: Donald_Rumsfeld, Asli: Tony_Blair
# Prediksi: Hugo_Chavez, Asli: Maria_Shriver
# Prediksi: John_Ashcroft, Asli: Megawati_Sukarnoputri
# Prediksi: John_Edwards, Asli: Vladimir_Putin
# Prediksi: George_W_Bush, Asli: Colin_Montgomerie
# Prediksi: Ariel_Sharon, Asli: Dominique_de_Villepin
# Prediksi: George_W_Bush, Asli: James_Blake
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Bill_Clinton, Asli: George_W_Bush
# Prediksi: Tony_Blair, Asli: Adrien_Brody
# Prediksi: Ai_Sugiyama, Asli: Monica_Seles
# Prediksi: Holly_Hunter, Asli: Howard_Dean
# Prediksi: Donald_Rumsfeld, Asli: Ricardo_Lagos
# Prediksi: Howard_Dean, Asli: Paul_Bremer
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Paradorn_Srichaphan, Asli: Steve_Lavin
# Prediksi: Michelle_Kwan, Asli: Holly_Hunter
# Prediksi: Gerhard_Schroeder, Asli: John_Ashcroft
# Prediksi: Alvaro_Uribe, Asli: Alvaro_Uribe
# Prediksi: George_W_Bush, Asli: John_Negroponte
# Prediksi: John_Ashcroft, Asli: Recep_Tayyip_Erdogan
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: Abdullah_Gul, Asli: Fidel_Castro
# Prediksi: Gerhard_Schroeder, Asli: Jason_Kidd
# Prediksi: Kim_Clijsters, Asli: Kim_Clijsters
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Albert_Costa, Asli: Ralf_Schumacher
# Prediksi: Cameron_Diaz, Asli: Jennifer_Aniston
# Prediksi: Martin_Scorsese, Asli: Heizo_Takenaka
# Prediksi: Bill_Gates, Asli: Donald_Rumsfeld
# Prediksi: Natalie_Coughlin, Asli: Ray_Romano
# Prediksi: Eduardo_Duhalde, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Gerhard_Schroeder, Asli: Dennis_Kucinich
# Prediksi: Renee_Zellweger, Asli: Junichiro_Koizumi
# Prediksi: Yashwant_Sinha, Asli: Atal_Bihari_Vajpayee
# Prediksi: Goldie_Hawn, Asli: Britney_Spears
# Prediksi: Ana_Guevara, Asli: David_Trimble
# Prediksi: Hans_Blix, Asli: John_Ashcroft
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Hugo_Chavez, Asli: Jackie_Chan
# Prediksi: Carlos_Menem, Asli: Jackie_Chan
# Prediksi: Hosni_Mubarak, Asli: Jean_Chretien
# Prediksi: John_Ashcroft, Asli: Michael_Douglas
# Prediksi: John_Travolta, Asli: Hugo_Chavez
# Prediksi: George_W_Bush, Asli: John_Ashcroft
# Prediksi: Tony_Blair, Asli: Michael_Chang
# Prediksi: Junichiro_Koizumi, Asli: Paul_Bremer
# Prediksi: Hans_Blix, Asli: Gunter_Pleuger
# Prediksi: Andre_Agassi, Asli: Andre_Agassi
# Prediksi: Sarah_Hughes, Asli: Michael_Bloomberg
# Prediksi: Shimon_Peres, Asli: Shimon_Peres
# Prediksi: Abdullah_Gul, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Jason_Kidd, Asli: Jason_Kidd
# Prediksi: Lindsay_Davenport, Asli: Monica_Seles
# Prediksi: Colin_Powell, Asli: John_Ashcroft
# Prediksi: Jiri_Novak, Asli: Jiri_Novak
# Prediksi: Bill_Gates, Asli: Rudolph_Giuliani
# Prediksi: Sarah_Jessica_Parker, Asli: Britney_Spears
# Prediksi: Martin_Scorsese, Asli: Rudolph_Giuliani
# Prediksi: Britney_Spears, Asli: Jennifer_Aniston
# Prediksi: Angelina_Jolie, Asli: Jennifer_Garner
# Prediksi: Jiang_Zemin, Asli: Carla_Del_Ponte
# Prediksi: Ron_Dittemore, Asli: Luis_Ernesto_Derbez_Bautista
# Prediksi: George_W_Bush, Asli: Colin_Powell
# Prediksi: Vicente_Fox, Asli: Gordon_Brown
# Prediksi: Michael_Bloomberg, Asli: Michael_Bloomberg
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: Recep_Tayyip_Erdogan, Asli: Tim_Henman
# Prediksi: Tom_Ridge, Asli: Laura_Bush
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Calista_Flockhart
# Prediksi: Igor_Ivanov, Asli: Gray_Davis
# Prediksi: Roger_Federer, Asli: Jennifer_Lopez
# Prediksi: Trent_Lott, Asli: Marcelo_Rios
# Prediksi: Nestor_Kirchner, Asli: Nestor_Kirchner
# Prediksi: Donald_Rumsfeld, Asli: Mahmoud_Abbas
# Prediksi: Carla_Del_Ponte, Asli: Alvaro_Uribe
# Prediksi: John_Ashcroft, Asli: Bill_Clinton
# Prediksi: Donald_Rumsfeld, Asli: Naji_Sabri
# Prediksi: Britney_Spears, Asli: Britney_Spears
# Prediksi: George_W_Bush, Asli: Gerhard_Schroeder
# Prediksi: Elizabeth_Hurley, Asli: Elton_John
# Prediksi: George_W_Bush, Asli: Jackie_Chan
# Prediksi: Igor_Ivanov, Asli: Roy_Moore
# Prediksi: Princess_Caroline, Asli: Sourav_Ganguly
# Prediksi: Hugo_Chavez, Asli: Vojislav_Kostunica
# Prediksi: Tony_Blair, Asli: Alejandro_Toledo
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Guillermo_Coria, Asli: Guillermo_Coria
# Prediksi: JK_Rowling, Asli: JK_Rowling
# Prediksi: Rendy Susanto, Asli: Rendy Susanto
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Ricardo_Lagos, Asli: Jean_Chretien
# Prediksi: James_Blake, Asli: James_Blake
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: John_Ashcroft, Asli: Tony_Stewart
# Prediksi: Lance_Bass, Asli: David_Trimble
# Prediksi: Donald_Rumsfeld, Asli: George_HW_Bush
# Prediksi: Bertie_Ahern, Asli: Recep_Tayyip_Erdogan
# Prediksi: Alejandro_Toledo, Asli: Tom_Cruise
# Prediksi: Tony_Blair, Asli: Carmen_Electra
# Prediksi: Paradorn_Srichaphan, Asli: Paradorn_Srichaphan
# Prediksi: Hosni_Mubarak, Asli: Jean_Chretien
# Prediksi: Donald_Rumsfeld, Asli: John_Bolton
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Tang_Jiaxuan, Asli: Tang_Jiaxuan
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Norah_Jones, Asli: Naomi_Watts
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Hugo_Chavez, Asli: Renee_Zellweger
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Mahathir_Mohamad
# Prediksi: Recep_Tayyip_Erdogan, Asli: Chen_Shui-bian
# Prediksi: Julie_Gerberding, Asli: Jennifer_Aniston
# Prediksi: Paradorn_Srichaphan, Asli: Bill_Frist
# Prediksi: George_W_Bush, Asli: Jennifer_Capriati
# Prediksi: Ron_Dittemore, Asli: Ron_Dittemore
# Prediksi: Robert_Blake, Asli: Robert_Blake
# Prediksi: Michael_Douglas, Asli: Martin_McGuinness
# Prediksi: Hugo_Chavez, Asli: Ludivine_Sagnier
# Prediksi: Nestor_Kirchner, Asli: Nestor_Kirchner
# Prediksi: Keanu_Reeves, Asli: Winona_Ryder
# Prediksi: Bill_Clinton, Asli: Ricardo_Lagos
# Prediksi: John_Kerry, Asli: Naji_Sabri
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Goldie_Hawn, Asli: Naomi_Watts
# Prediksi: Kofi_Annan, Asli: Kofi_Annan
# Prediksi: John_Kerry, Asli: Christine_Todd_Whitman
# Prediksi: Maria_Shriver, Asli: Serena_Williams
# Prediksi: Nestor_Kirchner, Asli: Nestor_Kirchner
# Prediksi: Sergey_Lavrov, Asli: Cesar_Gaviria
# Prediksi: Ariel_Sharon, Asli: Igor_Ivanov
# Prediksi: Donald_Rumsfeld, Asli: Edmund_Stoiber
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Hugo_Chavez, Asli: Tony_Blair
# Prediksi: Hans_Blix, Asli: John_Negroponte
# Prediksi: Donald_Rumsfeld, Asli: George_W_Bush
# Prediksi: Carlos_Menem, Asli: Sergey_Lavrov
# Prediksi: David_Heymann, Asli: Paul_Wolfowitz
# Prediksi: Lance_Armstrong, Asli: Andy_Roddick
# Prediksi: Donald_Rumsfeld, Asli: Joe_Lieberman
# Prediksi: Tony_Blair, Asli: Joan_Laporta
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: George_W_Bush, Asli: John_Edwards
# Prediksi: Tony_Blair, Asli: Charles_Moose
# Prediksi: David_Trimble, Asli: Colin_Powell
# Prediksi: Maria_Shriver, Asli: Julie_Gerberding
# Prediksi: Jennifer_Lopez, Asli: Maria_Shriver
# Prediksi: Gwyneth_Paltrow, Asli: Angela_Merkel
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Bertie_Ahern, Asli: Gerhard_Schroeder
# Prediksi: Tony_Blair, Asli: Joan_Laporta
# Prediksi: Donald_Rumsfeld, Asli: Mahathir_Mohamad
# Prediksi: John_Ashcroft, Asli: William_Ford_Jr
# Prediksi: George_W_Bush, Asli: Jose_Manuel_Durao_Barroso
# Prediksi: Hans_Blix, Asli: Matthew_Perry
# Prediksi: Matthew_Perry, Asli: John_Bolton
# Prediksi: Clint_Eastwood, Asli: Eduard_Shevardnadze
# Prediksi: Maria_Shriver, Asli: Julianne_Moore
# Prediksi: Jean_Chretien, Asli: Jean_Chretien
# Prediksi: George_W_Bush, Asli: Vicente_Fox
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Woody_Allen, Asli: Ariel_Sharon
# Prediksi: Lindsay_Davenport, Asli: Ali_Naimi
# Prediksi: John_Ashcroft, Asli: Sean_OKeefe
# Prediksi: Nestor_Kirchner, Asli: Tommy_Haas
# Prediksi: Kristanna_Loken, Asli: Carmen_Electra
# Prediksi: Nestor_Kirchner, Asli: Jennifer_Aniston
# Prediksi: Hillary_Clinton, Asli: Lleyton_Hewitt
# Prediksi: Tom_Daschle, Asli: Bill_McBride
# Prediksi: George_W_Bush, Asli: Jean_Charest
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: Kate_Hudson, Asli: Kate_Hudson
# Prediksi: John_Ashcroft, Asli: Bob_Stoops
# Prediksi: Nestor_Kirchner, Asli: Harrison_Ford
# Prediksi: Britney_Spears, Asli: Julianne_Moore
# Prediksi: Jimmy_Carter, Asli: Michael_Chiklis
# Prediksi: George_W_Bush, Asli: Jean_Chretien
# Prediksi: Holly_Hunter, Asli: Julianne_Moore
# Prediksi: John_Ashcroft, Asli: Megawati_Sukarnoputri
# Prediksi: Recep_Tayyip_Erdogan, Asli: Carlos_Moya
# Prediksi: Keanu_Reeves, Asli: Junichiro_Koizumi
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Hugo_Chavez, Asli: Pete_Sampras
# Prediksi: Bertie_Ahern, Asli: Gerhard_Schroeder
# Prediksi: Hugo_Chavez, Asli: Bill_Clinton
# Prediksi: Hugo_Chavez, Asli: Guillermo_Coria
# Prediksi: Venus_Williams, Asli: Serena_Williams
# Prediksi: Frank_Solich, Asli: Jennifer_Capriati
# Prediksi: Andre_Agassi, Asli: George_W_Bush
# Prediksi: Megawati_Sukarnoputri, Asli: Megawati_Sukarnoputri
# Prediksi: Bill_Clinton, Asli: Bill_Clinton
# Prediksi: Robert_Duvall, Asli: Spencer_Abraham
# Prediksi: Colin_Powell, Asli: Ariel_Sharon
# Prediksi: David_Beckham, Asli: Recep_Tayyip_Erdogan
# Prediksi: John_Ashcroft, Asli: Thomas_OBrien
# Prediksi: Renee_Zellweger, Asli: Hillary_Clinton
# Prediksi: Igor_Ivanov, Asli: Naji_Sabri
# Prediksi: Hans_Blix, Asli: Mohammed_Al-Douri
# Prediksi: Abdullah_Gul, Asli: Arnold_Schwarzenegger
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Jean-David_Levitte
# Prediksi: Kristanna_Loken, Asli: Michelle_Yeoh
# Prediksi: Tony_Blair, Asli: Ricardo_Lagos
# Prediksi: Saddam_Hussein, Asli: Javier_Solana
# Prediksi: Nicanor_Duarte_Frutos, Asli: Silvan_Shalom
# Prediksi: Michelle_Kwan, Asli: Laura_Bush
# Prediksi: Michelle_Kwan, Asli: Nancy_Pelosi
# Prediksi: Nestor_Kirchner, Asli: Luis_Ernesto_Derbez_Bautista
# Prediksi: Abdullah_Gul, Asli: Abdullah_Gul
# Prediksi: Anna_Kournikova, Asli: Valery_Giscard_dEstaing
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Colin_Powell, Asli: Chen_Shui-bian
# Prediksi: Tom_Daschle, Asli: Bill_McBride
# Prediksi: Gerhard_Schroeder, Asli: Hugo_Chavez
# Prediksi: Norah_Jones, Asli: Julianne_Moore
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Mahmoud_Abbas, Asli: Atal_Bihari_Vajpayee
# Prediksi: Jean-David_Levitte, Asli: Condoleezza_Rice
# Prediksi: Donald_Rumsfeld, Asli: Vladimir_Putin
# Prediksi: Jay_Garner, Asli: Mike_Martz
# Prediksi: Trent_Lott, Asli: George_W_Bush
# Prediksi: Tom_Ridge, Asli: Clint_Eastwood
# Prediksi: Colin_Powell, Asli: Dennis_Hastert
# Prediksi: Ari_Fleischer, Asli: Arnoldo_Aleman
# Prediksi: Silvio_Berlusconi, Asli: LeBron_James
# Prediksi: Lance_Armstrong, Asli: Hugh_Grant
# Prediksi: Bill_Clinton, Asli: John_Negroponte
# Prediksi: John_Manley, Asli: David_Nalbandian
# Prediksi: Igor_Ivanov, Asli: Dominique_de_Villepin
# Prediksi: Bill_Clinton, Asli: Queen_Elizabeth_II
# Prediksi: James_Blake, Asli: Hugo_Chavez
# Prediksi: Vicente_Fox, Asli: Vicente_Fox
# Prediksi: Ray_Romano, Asli: Halle_Berry
# Prediksi: Tony_Blair, Asli: Lleyton_Hewitt
# Prediksi: David_Beckham, Asli: Muhammad_Ali
# Prediksi: Hugo_Chavez, Asli: Serena_Williams
# Prediksi: Nestor_Kirchner, Asli: Eduard_Shevardnadze
# Prediksi: Jonathan_Edwards, Asli: Jeb_Bush
# Prediksi: Sergio_Vieira_De_Mello, Asli: Tom_Ridge
# Prediksi: Mark_Philippoussis, Asli: Jose_Maria_Aznar
# Prediksi: Justin_Timberlake, Asli: Jon_Gruden
# Prediksi: George_W_Bush, Asli: Donald_Rumsfeld
# Prediksi: Colin_Powell, Asli: Vaclav_Havel
# Prediksi: Igor_Ivanov, Asli: Paul_Burrell
# Prediksi: Gerhard_Schroeder, Asli: Charles_Moose
# Prediksi: Hosni_Mubarak, Asli: Fidel_Castro
# Prediksi: Gerhard_Schroeder, Asli: Rubens_Barrichello
# Prediksi: Vincent_Brooks, Asli: Tommy_Franks
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: George_W_Bush, Asli: Mohammed_Al-Douri
# Prediksi: George_W_Bush, Asli: Joschka_Fischer
# Prediksi: Michael_Bloomberg, Asli: Halle_Berry
# Prediksi: Ariel_Sharon, Asli: Atal_Bihari_Vajpayee
# Prediksi: Norah_Jones, Asli: Laura_Bush
# Prediksi: Tony_Blair, Asli: Joe_Lieberman
# Prediksi: Tony_Blair, Asli: Spencer_Abraham
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Gerhard_Schroeder, Asli: George_W_Bush
# Prediksi: John_Ashcroft, Asli: John_Negroponte
# Prediksi: Tony_Blair, Asli: Jan_Ullrich
# Prediksi: Colin_Powell, Asli: Fidel_Castro
# Prediksi: Andre_Agassi, Asli: Atal_Bihari_Vajpayee
# Prediksi: Donald_Rumsfeld, Asli: Jean_Chretien
# Prediksi: John_Edwards, Asli: Geoff_Hoon
# Prediksi: Nestor_Kirchner, Asli: George_W_Bush
# Prediksi: John_Ashcroft, Asli: John_Abizaid
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Xanana_Gusmao
# Prediksi: Roman_Polanski, Asli: John_Ashcroft
# Prediksi: Richard_Gephardt, Asli: Arnold_Schwarzenegger
# Prediksi: Al_Gore, Asli: Tom_Daschle
# Prediksi: Nestor_Kirchner, Asli: Nestor_Kirchner
# Prediksi: Recep_Tayyip_Erdogan, Asli: Recep_Tayyip_Erdogan
# Prediksi: Matthew_Perry, Asli: Alastair_Campbell
# Prediksi: Tim_Robbins, Asli: Jack_Straw
# Prediksi: Tony_Blair, Asli: Vicente_Fox
# Prediksi: Michelle_Kwan, Asli: Laura_Bush
# Prediksi: Tony_Blair, Asli: Brad_Johnson
# Prediksi: Natalie_Coughlin, Asli: Antonio_Palocci
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Rudolph_Giuliani
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Ana_Guevara, Asli: Lleyton_Hewitt
# Prediksi: John_Abizaid, Asli: John_Abizaid
# Prediksi: George_W_Bush, Asli: John_Negroponte
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Igor_Ivanov, Asli: John_Negroponte
# Prediksi: Pierce_Brosnan, Asli: Juan_Carlos_Ferrero
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Tony_Blair
# Prediksi: Clay_Aiken, Asli: Meryl_Streep
# Prediksi: Geoff_Hoon, Asli: Paula_Radcliffe
# Prediksi: Grant_Hackett, Asli: Juan_Carlos_Ferrero
# Prediksi: Tony_Blair, Asli: Paul_Burrell
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Trent_Lott, Asli: Robert_Mueller
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Lindsay_Davenport, Asli: Michael_Chiklis
# Prediksi: Yashwant_Sinha, Asli: John_Howard
# Prediksi: Antonio_Palocci, Asli: Antonio_Palocci
# Prediksi: Kim_Clijsters, Asli: Richard_Virenque
# Prediksi: Alvaro_Uribe, Asli: Alvaro_Uribe
# Prediksi: Lindsay_Davenport, Asli: Carlos_Moya
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Donald_Rumsfeld, Asli: Mahmoud_Abbas
# Prediksi: Paul_McCartney, Asli: Bob_Graham
# Prediksi: Nestor_Kirchner, Asli: Tung_Chee-hwa
# Prediksi: Hugo_Chavez, Asli: Roh_Moo-hyun
# Prediksi: Grant_Hackett, Asli: Tony_Blair
# Prediksi: Mark_Philippoussis, Asli: Jennifer_Capriati
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Tony_Blair, Asli: Yoko_Ono
# Prediksi: Sergio_Vieira_De_Mello, Asli: John_Ashcroft
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: John_Travolta, Asli: Richard_Virenque
# Prediksi: George_W_Bush, Asli: Mark_Hurlbert
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Hamid_Karzai, Asli: Cesar_Gaviria
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: John_Ashcroft, Asli: John_Negroponte
# Prediksi: Tony_Blair, Asli: Hugo_Chavez
# Prediksi: Michael_Douglas, Asli: Thaksin_Shinawatra
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Hamid_Karzai
# Prediksi: Jay_Garner, Asli: Mahmoud_Abbas
# Prediksi: Cesar_Gaviria, Asli: Tony_Blair
# Prediksi: George_W_Bush, Asli: Christine_Todd_Whitman
# Prediksi: Colin_Powell, Asli: Hamid_Karzai
# Prediksi: Jennifer_Lopez, Asli: Laura_Bush
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Lucy_Liu
# Prediksi: Hugh_Grant, Asli: Zhu_Rongji
# Prediksi: Renee_Zellweger, Asli: John_Ashcroft
# Prediksi: Lance_Armstrong, Asli: Harrison_Ford
# Prediksi: Colin_Powell, Asli: Fujio_Cho
# Prediksi: Hugo_Chavez, Asli: John_Ashcroft
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Norah_Jones, Asli: Serena_Williams
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: Roman_Polanski, Asli: Richard_Gephardt
# Prediksi: Kofi_Annan, Asli: Kofi_Annan
# Prediksi: Guillermo_Coria, Asli: Guillermo_Coria
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Vicente_Fox, Asli: Carlos_Menem
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Ariel_Sharon, Asli: Jose_Serra
# Prediksi: Michael_Bloomberg, Asli: Mohammed_Al-Douri
# Prediksi: Ariel_Sharon, Asli: David_Beckham
# Prediksi: Angelina_Jolie, Asli: Gloria_Macapagal_Arroyo
# Prediksi: Kofi_Annan, Asli: Kofi_Annan
# Prediksi: Renee_Zellweger, Asli: Keanu_Reeves
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Gonzalo_Sanchez_de_Lozada, Asli: Bill_Clinton
# Prediksi: Scott_McClellan, Asli: Hosni_Mubarak
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Arnold_Schwarzenegger, Asli: Maria_Shriver
# Prediksi: Tony_Blair, Asli: Yashwant_Sinha
# Prediksi: Catherine_Deneuve, Asli: Madonna
# Prediksi: Hu_Jintao, Asli: Heizo_Takenaka
# Prediksi: Richard_Armitage, Asli: Roh_Moo-hyun
# Prediksi: Serena_Williams, Asli: Hillary_Clinton
# Prediksi: Tony_Blair, Asli: George_Pataki
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Tom_Ridge, Asli: Catherine_Zeta-Jones
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: Queen_Elizabeth_II
# Prediksi: Serena_Williams, Asli: Laura_Bush
# Prediksi: Ralf_Schumacher, Asli: Lindsay_Davenport
# Prediksi: George_W_Bush, Asli: Steffi_Graf
# Prediksi: Kim_Clijsters, Asli: Michael_Schumacher
# Prediksi: Hugo_Chavez, Asli: James_Kelly
# Prediksi: Yoko_Ono, Asli: Sheryl_Crow
# Prediksi: Andre_Agassi, Asli: Rudolph_Giuliani
# Prediksi: Jean_Chretien, Asli: Gerhard_Schroeder
# Prediksi: George_W_Bush, Asli: Tony_Blair
# Prediksi: Steffi_Graf, Asli: Monica_Seles
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Michael_Bloomberg, Asli: Jelena_Dokic
# Prediksi: Hu_Jintao, Asli: Hu_Jintao
# Prediksi: Habib_Rizieq, Asli: Condoleezza_Rice
# Prediksi: Richard_Gephardt, Asli: James_Kelly
# Prediksi: Bill_Graham, Asli: James_Wolfensohn
# Prediksi: John_Allen_Muhammad, Asli: John_Allen_Muhammad
# Prediksi: Tony_Blair, Asli: Gray_Davis
# Prediksi: Ariel_Sharon, Asli: George_HW_Bush
# Prediksi: George_W_Bush, Asli: King_Abdullah_II
# Prediksi: Gerhard_Schroeder, Asli: Muhammad_Ali
# Prediksi: Ariel_Sharon, Asli: Yashwant_Sinha
# Prediksi: Donald_Rumsfeld, Asli: Richard_Gephardt
# Prediksi: Gerhard_Schroeder, Asli: Arnold_Schwarzenegger
# Prediksi: Lance_Armstrong, Asli: Paul_Martin
# Prediksi: Igor_Ivanov, Asli: Robert_Zoellick
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Clay_Aiken, Asli: Salma_Hayek
# Prediksi: Bill_Gates, Asli: Amelia_Vega
# Prediksi: George_W_Bush, Asli: Vladimir_Putin
# Prediksi: Dick_Cheney, Asli: Colin_Powell
# Prediksi: Andy_Roddick, Asli: Mike_Weir
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Juan_Carlos_Ferrero, Asli: Amelie_Mauresmo
# Prediksi: George_W_Bush, Asli: Gerhard_Schroeder
# Prediksi: Donald_Rumsfeld, Asli: Bill_Simon
# Prediksi: Gene_Robinson, Asli: Colin_Powell
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Donald_Rumsfeld, Asli: John_Bolton
# Prediksi: Tony_Blair, Asli: Donald_Rumsfeld
# Prediksi: Lucy_Liu, Asli: Oscar_De_La_Hoya
# Prediksi: Tom_Ridge, Asli: Laura_Bush
# Prediksi: Serena_Williams, Asli: Serena_Williams
# Prediksi: Fujio_Cho, Asli: Silvio_Berlusconi
# Prediksi: Tom_Cruise, Asli: Tom_Cruise
# Prediksi: Norah_Jones, Asli: Jean_Chretien
# Prediksi: Tony_Blair, Asli: Prince_Charles
# Prediksi: Angelina_Jolie, Asli: Angelina_Jolie
# Prediksi: Kate_Hudson, Asli: Angelina_Jolie
# Prediksi: Scott_McClellan, Asli: Nicole_Kidman
# Prediksi: Donald_Rumsfeld, Asli: Edmund_Stoiber
# Prediksi: Colin_Powell, Asli: Howard_Dean
# Prediksi: Ana_Guevara, Asli: Colin_Powell
# Prediksi: Recep_Tayyip_Erdogan, Asli: Gloria_Macapagal_Arroyo
# Prediksi: Matthew_Perry, Asli: Harrison_Ford
# Prediksi: Nestor_Kirchner, Asli: Zhu_Rongji
# Prediksi: Tony_Blair, Asli: Alvaro_Uribe
# Prediksi: Donald_Rumsfeld, Asli: Tom_Harkin
# Prediksi: George_W_Bush, Asli: Gerhard_Schroeder
# Prediksi: Abdullah_Gul, Asli: Abdullah_Gul
# Prediksi: Mark_Philippoussis, Asli: Hugo_Chavez
# Prediksi: Ari_Fleischer, Asli: Ari_Fleischer
# Prediksi: George_W_Bush, Asli: Pierce_Brosnan
# Prediksi: Hugo_Chavez, Asli: Lindsay_Davenport
# Prediksi: Nestor_Kirchner, Asli: Jeremy_Greenstock
# Prediksi: Ralf_Schumacher, Asli: Ricardo_Sanchez
# Prediksi: Dick_Cheney, Asli: John_Negroponte
# Prediksi: Yoko_Ono, Asli: Adrien_Brody
# Prediksi: Hans_Blix, Asli: Hans_Blix
# Prediksi: John_Ashcroft, Asli: Vicente_Fox
# Prediksi: Norm_Coleman, Asli: Colin_Farrell
# Prediksi: Roh_Moo-hyun, Asli: Roh_Moo-hyun
# Prediksi: Donald_Rumsfeld, Asli: Jean-Pierre_Raffarin
# Prediksi: Silvio_Berlusconi, Asli: Tommy_Thompson
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Ray_Romano
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Hillary_Clinton, Asli: Christine_Todd_Whitman
# Prediksi: Donald_Rumsfeld, Asli: William_Donaldson
# Prediksi: Donald_Rumsfeld, Asli: Vicente_Fox
# Prediksi: Holly_Hunter, Asli: Naomi_Watts
# Prediksi: Jeremy_Greenstock, Asli: Jeremy_Greenstock
# Prediksi: Norah_Jones, Asli: Pamela_Anderson
# Prediksi: Tony_Blair, Asli: Paul_Burrell
# Prediksi: Scott_McClellan, Asli: Joseph_Biden
# Prediksi: George_W_Bush, Asli: Jeb_Bush
# Prediksi: Gerhard_Schroeder, Asli: Gerhard_Schroeder
# Prediksi: Recep_Tayyip_Erdogan, Asli: Jackie_Chan
# Prediksi: George_W_Bush, Asli: Vladimir_Putin
# Prediksi: Sergey_Lavrov, Asli: Sergey_Lavrov
# Prediksi: Gerhard_Schroeder, Asli: George_W_Bush
# Prediksi: Mark_Philippoussis, Asli: Jose_Maria_Aznar
# Prediksi: Jean_Charest, Asli: Princess_Caroline
# Prediksi: Silvio_Berlusconi, Asli: Chanda_Rubin
# Prediksi: Maria_Soledad_Alvear_Valenzuela, Asli: Arminio_Fraga
# Prediksi: Holly_Hunter, Asli: Holly_Hunter
# Prediksi: Billy_Crystal, Asli: Saddam_Hussein
# Prediksi: Scott_McClellan, Asli: Jake_Gyllenhaal
# Prediksi: Robert_Duvall, Asli: Robert_Duvall
# Prediksi: Nancy_Pelosi, Asli: Sheryl_Crow
# Prediksi: Martin_Scorsese, Asli: Atal_Bihari_Vajpayee
# Prediksi: Scott_McClellan, Asli: Tony_Blair
# Prediksi: Lindsay_Davenport, Asli: Christine_Baumgartner
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Colin_Powell, Asli: Jacques_Chirac
# Prediksi: Oscar_De_La_Hoya, Asli: Tony_Blair
# Prediksi: Lance_Bass, Asli: Julianne_Moore
# Prediksi: Kevin_Costner, Asli: Peter_Struck
# Prediksi: Kim_Ryong-sung, Asli: Nestor_Kirchner
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Michael_Jackson, Asli: Peter_Struck
# Prediksi: Jiang_Zemin, Asli: Cruz_Bustamante
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Luiz_Inacio_Lula_da_Silva
# Prediksi: Ari_Fleischer, Asli: Jeong_Se-hyun
# Prediksi: Donald_Rumsfeld, Asli: Amelie_Mauresmo
# Prediksi: John_Ashcroft, Asli: John_Stockton
# Prediksi: Vicente_Fox, Asli: Alejandro_Toledo
# Prediksi: Sergey_Lavrov, Asli: Alejandro_Toledo
# Prediksi: Michelle_Kwan, Asli: Jennifer_Garner
# Prediksi: Sergey_Lavrov, Asli: Nestor_Kirchner
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Bill_Graham, Asli: Ari_Fleischer
# Prediksi: Tony_Blair, Asli: Antonio_Banderas
# Prediksi: Gloria_Macapagal_Arroyo, Asli: Benazir_Bhutto
# Prediksi: Larry_Brown, Asli: Nadia_Petrova
# Prediksi: Jiang_Zemin, Asli: Luis_Gonzalez_Macchi
# Prediksi: Nancy_Pelosi, Asli: Winona_Ryder
# Prediksi: Queen_Elizabeth_II, Asli: Queen_Elizabeth_II
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Sergio_Vieira_De_Mello, Asli: Valery_Giscard_dEstaing
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Hans_Blix, Asli: Hans_Blix
# Prediksi: Jean-David_Levitte, Asli: Nicole_Kidman
# Prediksi: Hugo_Chavez, Asli: Tung_Chee-hwa
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Donald_Rumsfeld, Asli: Carla_Del_Ponte
# Prediksi: Richard_Armitage, Asli: George_W_Bush
# Prediksi: Vicente_Fox, Asli: George_W_Bush
# Prediksi: Sergio_Vieira_De_Mello, Asli: Sergio_Vieira_De_Mello
# Prediksi: Donald_Rumsfeld, Asli: Pervez_Musharraf
# Prediksi: Abdullah_Gul, Asli: Kamal_Kharrazi
# Prediksi: Gerhard_Schroeder, Asli: Paul_Bremer
# Prediksi: Donald_Rumsfeld, Asli: Ricardo_Lagos
# Prediksi: Mark_Philippoussis, Asli: Mark_Hurlbert
# Prediksi: Saddam_Hussein, Asli: Mohammad_Khatami
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: John_Ashcroft, Asli: Colin_Powell
# Prediksi: Carlos_Menem, Asli: George_W_Bush
# Prediksi: Recep_Tayyip_Erdogan, Asli: Serena_Williams
# Prediksi: Rendy Susanto, Asli: Rendy Susanto
# Prediksi: Lleyton_Hewitt, Asli: Lleyton_Hewitt
# Prediksi: Keanu_Reeves, Asli: Taha_Yassin_Ramadan
# Prediksi: Cesar_Gaviria, Asli: Hugo_Chavez
# Prediksi: John_Negroponte, Asli: John_Negroponte
# Prediksi: Andre_Agassi, Asli: Hans_Blix
# Prediksi: Renee_Zellweger, Asli: Arnold_Schwarzenegger
# Prediksi: Hugh_Grant, Asli: Heidi_Klum
# Prediksi: Hugo_Chavez, Asli: Hugo_Chavez
# Prediksi: Saddam_Hussein, Asli: Scott_McClellan
# Prediksi: Cesar_Gaviria, Asli: Hamid_Karzai
# Prediksi: Ariel_Sharon, Asli: Ariel_Sharon
# Prediksi: John_Ashcroft, Asli: Sylvester_Stallone
# Prediksi: Mohammad_Khatami, Asli: Mohammad_Khatami
# Prediksi: Donald_Rumsfeld, Asli: Michael_Powell
# Prediksi: Tom_Ridge, Asli: Matthew_Perry
# Prediksi: Fernando_Henrique_Cardoso, Asli: Vaclav_Havel
# Prediksi: Junichiro_Koizumi, Asli: Sergey_Lavrov
# Prediksi: Scott_McClellan, Asli: Tom_Ridge
# Prediksi: Peter_Struck, Asli: Charlton_Heston
# Prediksi: Bill_Gates, Asli: Fidel_Castro
# Prediksi: Howard_Dean, Asli: Howard_Dean
# Prediksi: Carlos_Moya, Asli: Carlos_Moya
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Steven_Spielberg
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: George_W_Bush, Asli: Juan_Carlos_Ferrero
# Prediksi: Emma_Watson, Asli: Megawati_Sukarnoputri
# Prediksi: Nancy_Pelosi, Asli: Nancy_Pelosi
# Prediksi: George_W_Bush, Asli: John_McCain
# Prediksi: Maria_Shriver, Asli: Emanuel_Ginobili
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Angelina_Jolie, Asli: Queen_Rania
# Prediksi: Robert_Blake, Asli: George_W_Bush
# Prediksi: John_Travolta, Asli: Rob_Marshall
# Prediksi: Jason_Kidd, Asli: Nicanor_Duarte_Frutos
# Prediksi: Jean-David_Levitte, Asli: Erika_Harold
# Prediksi: Ariel_Sharon, Asli: Gerhard_Schroeder
# Prediksi: Jacques_Rogge, Asli: Hosni_Mubarak
# Prediksi: Lance_Bass, Asli: George_W_Bush
# Prediksi: Ari_Fleischer, Asli: John_Abizaid
# Prediksi: David_Beckham, Asli: John_Bolton
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Amelie_Mauresmo, Asli: Jean_Charest
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Jeb_Bush, Asli: Roy_Moore
# Prediksi: Donald_Rumsfeld, Asli: Charlton_Heston
# Prediksi: John_Ashcroft, Asli: Hitomi_Soga
# Prediksi: Roh_Moo-hyun, Asli: Zhu_Rongji
# Prediksi: Alvian Devano Sugiarto, Asli: Serena_Williams
# Prediksi: Tony_Blair, Asli: Igor_Ivanov
# Prediksi: Hugo_Chavez, Asli: Spencer_Abraham
# Prediksi: Ariel_Sharon, Asli: Joschka_Fischer
# Prediksi: Yoko_Ono, Asli: Julie_Gerberding
# Prediksi: Recep_Tayyip_Erdogan, Asli: Mark_Philippoussis
# Prediksi: Ariel_Sharon, Asli: Rudolph_Giuliani
# Prediksi: Bill_Gates, Asli: Hillary_Clinton
# Prediksi: Tony_Stewart, Asli: Susan_Sarandon
# Prediksi: Bill_Gates, Asli: Chanda_Rubin
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: Amelie_Mauresmo
# Prediksi: Bernard_Law, Asli: Mahmoud_Abbas
# Prediksi: Keanu_Reeves, Asli: Jeremy_Greenstock
# Prediksi: John_Ashcroft, Asli: Gray_Davis
# Prediksi: Tom_Daschle, Asli: George_W_Bush
# Prediksi: Andre_Agassi, Asli: Andre_Agassi
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Bernard_Law, Asli: John_Abizaid
# Prediksi: Nestor_Kirchner, Asli: Pete_Sampras
# Prediksi: George_W_Bush, Asli: Jacques_Chirac
# Prediksi: Robert_Zoellick, Asli: Michael_Jackson
# Prediksi: Amelie_Mauresmo, Asli: Amelie_Mauresmo
# Prediksi: Richard_Myers, Asli: Charles_Moose
# Prediksi: Tony_Blair, Asli: Amelie_Mauresmo
# Prediksi: Tony_Blair, Asli: Igor_Ivanov
# Prediksi: Colin_Powell, Asli: George_W_Bush
# Prediksi: Yashwant_Sinha, Asli: Alejandro_Toledo
# Prediksi: Jonathan_Edwards, Asli: Gil_de_Ferran
# Prediksi: Tony_Blair, Asli: Bulent_Ecevit
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Jean-David_Levitte, Asli: Juan_Pablo_Montoya
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Pedro_Malan, Asli: Kim_Dae-jung
# Prediksi: Donald_Rumsfeld, Asli: Trent_Lott
# Prediksi: Abdullah_Gul, Asli: Rubens_Barrichello
# Prediksi: Catherine_Zeta-Jones, Asli: Nicole_Kidman
# Prediksi: Norah_Jones, Asli: Jean_Charest
# Prediksi: Sarah_Hughes, Asli: Emma_Watson
# Prediksi: Yashwant_Sinha, Asli: John_Ashcroft
# Prediksi: George_W_Bush, Asli: Colin_Powell
# Prediksi: Colin_Powell, Asli: Benjamin_Netanyahu
# Prediksi: George_W_Bush, Asli: Hugo_Chavez
# Prediksi: John_Ashcroft, Asli: Bob_Graham
# Prediksi: Britney_Spears, Asli: Kate_Hudson
# Prediksi: Tony_Blair, Asli: Tony_Blair
# Prediksi: Hugo_Chavez, Asli: Junichiro_Koizumi
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Norah_Jones, Asli: Hitomi_Soga
# Prediksi: Megawati_Sukarnoputri, Asli: Megawati_Sukarnoputri
# Prediksi: Tony_Blair, Asli: George_W_Bush
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Jose_Maria_Aznar, Asli: Catherine_Zeta-Jones
# Prediksi: Abdullah_Gul, Asli: Taha_Yassin_Ramadan
# Prediksi: Ray_Romano, Asli: Arnold_Schwarzenegger
# Prediksi: Michael_Bloomberg, Asli: Jelena_Dokic
# Prediksi: Jennifer_Capriati, Asli: Ray_Romano
# Prediksi: Norah_Jones, Asli: Ashanti
# Prediksi: Donald_Rumsfeld, Asli: Nicanor_Duarte_Frutos
# Prediksi: Hans_Blix, Asli: Atal_Bihari_Vajpayee
# Prediksi: Bernard_Law, Asli: Colin_Powell
# Prediksi: Andy_Roddick, Asli: Andy_Roddick
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Donald_Rumsfeld, Asli: Colin_Powell
# Prediksi: Saddam_Hussein, Asli: Saddam_Hussein
# Prediksi: Michael_Bloomberg, Asli: Silvio_Berlusconi
# Prediksi: Colin_Powell, Asli: John_Howard
# Prediksi: Nia_Vardalos, Asli: Nia_Vardalos
# Prediksi: Nestor_Kirchner, Asli: Michael_Bloomberg
# Prediksi: Gerhard_Schroeder, Asli: Keanu_Reeves
# Prediksi: Donald_Rumsfeld, Asli: Hans_Blix
# Prediksi: Kim_Clijsters, Asli: Jim_Furyk
# Prediksi: Colin_Powell, Asli: Jack_Straw
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Jon_Gruden, Asli: Gray_Davis
# Prediksi: Colin_Powell, Asli: Lance_Armstrong
# Prediksi: Jiang_Zemin, Asli: Hans_Blix
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Ai_Sugiyama, Asli: Megawati_Sukarnoputri
# Prediksi: Lance_Bass, Asli: Angelina_Jolie
# Prediksi: Colin_Powell, Asli: Ricardo_Lagos
# Prediksi: Donald_Rumsfeld, Asli: Jay_Garner
# Prediksi: Nancy_Pelosi, Asli: Nancy_Pelosi
# Prediksi: Colin_Powell, Asli: Fidel_Castro
# Prediksi: Rendy Susanto, Asli: Rendy Susanto
# Prediksi: Roman_Polanski, Asli: George_W_Bush
# Prediksi: Andre_Agassi, Asli: John_Snow
# Prediksi: Tony_Blair, Asli: Bill_Simon
# Prediksi: Tony_Blair, Asli: Zinedine_Zidane
# Prediksi: Jean-David_Levitte, Asli: Pedro_Malan
# Prediksi: Tony_Blair, Asli: Richard_Myers
# Prediksi: Hans_Blix, Asli: Alvaro_Uribe
# Prediksi: Colin_Powell, Asli: Colin_Powell
# Prediksi: Saddam_Hussein, Asli: Roger_Moore
# Prediksi: Tony_Blair, Asli: Guillermo_Coria
# Prediksi: Ralf_Schumacher, Asli: Winona_Ryder
# Prediksi: George_W_Bush, Asli: Ann_Veneman
# Prediksi: George_W_Bush, Asli: George_W_Bush
# Prediksi: Justine_Pasek, Asli: Justine_Pasek
# Prediksi: Tom_Ridge, Asli: Dennis_Hastert
# Prediksi: Anna_Kournikova, Asli: Jennifer_Lopez
# Prediksi: Vojislav_Kostunica, Asli: Jose_Maria_Aznar
# Prediksi: Rainer_Schuettler, Asli: Carlos_Moya
# Prediksi: Bill_Clinton, Asli: Richard_Myers
# Prediksi: Luiz_Inacio_Lula_da_Silva, Asli: Taha_Yassin_Ramadan
# Prediksi: Lance_Armstrong, Asli: Christine_Baumgartner
# Prediksi: Tony_Blair, Asli: Mireya_Moscoso
# Prediksi: Juan_Carlos_Ferrero, Asli: Wayne_Ferreira
# Prediksi: Hans_Blix, Asli: Hans_Blix
# Prediksi: Junichiro_Koizumi, Asli: Junichiro_Koizumi
# Prediksi: Mark_Philippoussis, Asli: Guillermo_Coria
# Prediksi: Tony_Blair, Asli: Hillary_Clinton
# Prediksi: Donald_Rumsfeld, Asli: Donald_Rumsfeld
# Prediksi: Tony_Blair, Asli: Enrique_Bolanos

# %% [markdown]
# # Logistic Regression & Random Forest

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Load Haar Cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def detect_faces_and_preprocess(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Deteksi wajah
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(faces) > 0:
        # Ambil bounding box wajah pertama
        (x, y, w, h) = faces[0]
        face_img = img[y:y+h, x:x+w]  # Crop wajah
        face_img = cv2.resize(face_img, (224, 224))  # Resize untuk MobileNet
        face_img = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)  # Konversi ke RGB
        return face_img
    else:
        return None  # Jika tidak ada wajah, kembalikan None

# %%
# Fungsi untuk memuat gambar wajah dan label
def load_images_and_labels(dataset_path):
    images = []
    labels = []
    label_map = {}
    label_count = 0

    for folder_name in os.listdir(dataset_path):
        person_folder = os.path.join(dataset_path, folder_name)

        if os.path.isdir(person_folder):
            # Hanya ambil gambar yang jumlahnya >= 5
            image_files = [f for f in os.listdir(person_folder) if f.endswith(('jpg', 'jpeg', 'png'))]
            if len(image_files) >= 5:
                label_map[label_count] = folder_name  # Menyimpan label ke nama orang
                for image_file in image_files:
                    img_path = os.path.join(person_folder, image_file)
                    face_img = detect_faces_and_preprocess(img_path)
                    if face_img is not None:
                        images.append(face_img)
                        labels.append(label_count)
                label_count += 1

    return np.array(images), np.array(labels), label_map

# %%
def extract_features(images, batch_size=32):
    model = MobileNetV2(weights='imagenet', include_top=False, pooling='avg')
    features = []

    # Proses dalam batch
    for i in range(0, len(images), batch_size):
        batch_images = images[i:i + batch_size]
        batch_features = model.predict(batch_images)
        features.append(batch_features)

    # Gabungkan semua batch menjadi satu array
    return np.vstack(features)

# %%
dataset_path = '/content/Dataset'

# %%
# Memuat gambar dan label
images, labels, label_map = load_images_and_labels(dataset_path)

# Normalisasi gambar dan preprocessing input untuk MobileNet
images = preprocess_input(images)

# Ekstraksi fitur menggunakan MobileNet
features = extract_features(images)
# Out:
# <ipython-input-6-2f371698ee99>:2: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   model = MobileNetV2(weights='imagenet', include_top=False, pooling='avg')
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 981ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 974ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 995ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 999ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 994ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 997ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
# Membagi data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
# Model Logistic Regression
model_lr = OneVsRestClassifier(LogisticRegression(max_iter=1000))
model_lr.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(max_iter=1000))

# %%
# Prediksi dan evaluasi
y_pred_lr = model_lr.predict(X_test)
accuracy_lr = accuracy_score(y_test, y_pred_lr)
print(f"Akurasi Logistic Regression: {accuracy_lr * 100:.2f}%")
# Out:
# Akurasi Logistic Regression: 45.90%

# %%
# Model Random Forest
model_rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
# Prediksi dan evaluasi
y_pred_rf = model_rf.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Akurasi Random Forest: {accuracy_rf * 100:.2f}%")
# Out:
# Akurasi Random Forest: 14.32%
